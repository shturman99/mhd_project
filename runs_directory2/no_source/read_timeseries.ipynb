# %% [markdown]
# # Setup python session and notebook
#
# We start with importing what we will need. Note here that we want to have matplotlib to do the plot in our notebook! That means we are free to zoom and navigate in the plot even after plotting. Check out different possiblities on your own, please.

# %%
# %matplotlib inline
import numpy as np
import pencil as pc
import matplotlib.pyplot as plt

# %% [markdown]
# # Get simulation as object
#
# We will use the sample in 'pencil-code/python/tutorials/sample_simulations/2d_streaming_instability' in this notebook. So lets start by reading that simulation in as a simulation object.

# %%
SIM = pc.get_sim('')
# Out:
# File /home/mgurgeni/programming/GWfromSM/run_directories/512_1e2_1e4_2p5e9_1em6a/data/proc980/dim.dat could not be opened.
# ? WARNING: Couldnt load grid for /home/mgurgeni/programming/GWfromSM/run_directories/512_1e2_1e4_2p5e9_1em6a

# %% [markdown]
# # Read timeseries
# Thats already it! Lets get the timeseries and plot it!
#
# Note: If you want to suppress output from a python command, append ; to that line.

# %%
ts = pc.read.ts(file_name="time_series.250221.1159",datadir=SIM.datadir);
# Out:
# Read 12000 lines.

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(ts.t, ts.EEGW, label=r'$EEGW$')
ax.plot(ts.t, ts.EEM, label=r'$EEM$')
ax.legend()

# %% [markdown]
# # See available content of timeseries
# The timeseries object stores all you available quantity timeseries. To get an overview use ts.<TAB> to the via autocomplete or use

# %%
print([s for s in dir(ts) ])
# Out:
# ['EEGW', 'EEK', 'EEM', 'STimp2', 'STimpt', 'STrep2', 'STrept', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'abm', 'bmax', 'bmx', 'bmy', 'bmz', 'brms', 'divu2m', 'dt', 'epsK', 'epsM', 'gg2m', 'hTimp2', 'hTimpt', 'hTrep2', 'hTrept', 'hrms', 'it', 'jbm', 'keys', 'mu5m', 'mu5max', 'mu5rms', 'o2m', 'o2u2m', 'oum', 'ourms', 'oxurms', 'read', 'rhom', 't', 'ujxbm', 'umax', 'urms']

# %% [markdown]
# # Plot all density timeseries in two lines

# %%
for q in dir(ts):
    if not q.startswith('__') and q!="keys" and q!="read": 
        print(q)
        plt.plot(ts.t, getattr(ts, q))
        plt.title(q)
        plt.show()
# Out:
# EEGW
# EEK
# EEM
# STimp2
# STimpt
# STrep2
# STrept
# abm
# bmax
# bmx
# bmy
# bmz
# brms
# divu2m
# dt
# epsK
# epsM
# gg2m
# hTimp2
# hTimpt
# hTrep2
# hTrept
# hrms
# it
# jbm
# mu5m
# mu5max
# mu5rms
# o2m
# o2u2m
# oum
# ourms
# oxurms
# rhom
# t
# ujxbm
# umax
# urms
